# %%
import warnings
warnings.simplefilter("ignore")
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)
import matplotlib.pyplot as plt
# %matplotlib inline
import gensim
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping
from keras.initializers import Constant
from keras.layers import (Input, Embedding, SpatialDropout1D, Bidirectional,
                          GlobalAveragePooling1D, GlobalMaxPooling1D, add,
                          LSTM, CuDNNLSTM, GRU, CuDNNGRU, concatenate, Dropout, Dense, Activation)
from keras.models import Model
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
NUM_WORDS = 50000
MAXLEN = 250
EMBEDDING_DIM = 300

# %%
class RocAucEvaluation(Callback):
    def __init__(self, validation_data):
        self.X_val, self.y_val = validation_data
    def on_epoch_end(self, epoch, logs=None):
        y_pred = self.model.predict(self.X_val, verbose=0)
        score = roc_auc_score(self.y_val, y_pred)
        print("\n ROC-AUC - epoch: {:d} - score: {:.6f}".format(epoch + 1, score))

# %%
train = pd.read_csv('data/train_preprocessed.csv')
test = pd.read_csv('data/test_preprocessed.csv')
train['comment_text'].fillna("", inplace=True)
test['comment_text'].fillna("", inplace=True)
classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
X_train_raw, y_train = train['comment_text'].str.lower(), train[classes].values
X_test_raw = test['comment_text'].str.lower()
tk = Tokenizer(num_words=NUM_WORDS)
tk.fit_on_texts(X_train_raw)
X_train = tk.texts_to_sequences(X_train_raw)
X_test = tk.texts_to_sequences(X_test_raw)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=0)
X_train = pad_sequences(X_train, maxlen=MAXLEN)
X_valid = pad_sequences(X_valid, maxlen=MAXLEN)
X_test = pad_sequences(X_test, maxlen=MAXLEN)
nb_words = min(NUM_WORDS, len(tk.word_index) + 1)

# %%
def get_coefs(word, *arr):
    return word, np.asarray(arr, dtype='float32')


def get_embedding(pretrained_word_vectors):
    if pretrained_word_vectors == "google":
        EMBEDDING_PATH = "../embeddings/GoogleNews-vectors-negative300.bin"
        embedding_index = gensim.models.KeyedVectors.load_word2vec_format(EMBEDDING_PATH, binary=True)
    if pretrained_word_vectors == "glove":
        EMBEDDING_PATH = "../embeddings/glove.840B.300d.txt"
        embedding_index = dict(get_coefs(*o.strip().split(" ")) for o in open(EMBEDDING_PATH))
    elif pretrained_word_vectors == "fasttext":
        EMBEDDING_PATH = "../embeddings/crawl-300d-2M.vec"
        embedding_index = dict(get_coefs(*o.strip().split(" ")) for o in open(EMBEDDING_PATH))
    embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
    for word, i in tk.word_index.items():
        if i >= NUM_WORDS:
            continue
        if pretrained_word_vectors == "google":
            try:
                embedding_vector = embedding_index.get_vector(word)
            except Exception:
                continue
            embedding_matrix[i] = embedding_vector
        else:
            embedding_vector = embedding_index.get(word)
            if embedding_vector is not None:
                embedding_matrix[i] = embedding_vector
    return embedding_matrix

# %%
def build_model(embedding_matrix):
    inputs = Input(shape=(MAXLEN,))
    x = Embedding(nb_words, EMBEDDING_DIM,
                  embeddings_initializer=Constant(embedding_matrix),
                  trainable=False)(inputs)
    x = SpatialDropout1D(0.2)(x)
    x = Bidirectional(CuDNNGRU(128, return_sequences=True))(x)
    x = Bidirectional(CuDNNGRU(128, return_sequences=True))(x)
    hidden = concatenate([GlobalMaxPooling1D()(x), GlobalAveragePooling1D()(x)])
    #hidden = add([hidden, Dense(512, activation='relu')(hidden)])
    #hidden = add([hidden, Dense(512, activation='relu')(hidden)])
    outputs = Dense(6, activation="sigmoid")(hidden)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='binary_crossentropy', optimizer="adam", metrics=['accuracy'])
    return model

# %%
embedding_matrix = get_embedding("glove")
roc_eval = RocAucEvaluation(validation_data=(X_valid, y_valid))
early_stopping = EarlyStopping(patience=3, restore_best_weights=True)
n_models = 5
pred = np.zeros((X_test.shape[0], 6))
for _ in range(n_models):
    model = build_model(embedding_matrix=embedding_matrix)
    model.fit(X_train, y_train, batch_size=128, epochs=10,
              validation_data=(X_valid, y_valid),
              callbacks = [roc_eval, early_stopping])
    pred += model.predict(X_test, batch_size=1024, verbose=1)
pred /= n_models
submission = pd.read_csv("data/sample_submission.csv")
submission[classes] = pred
submission.to_csv("submission/v5_GRU_glove_preprocess_submission.csv.gz", compression="gzip", index=False)
# Out:
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 73s 510us/step - loss: 0.0541 - acc: 0.9804 - val_loss: 0.0425 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 1 - score: 0.986448
# Epoch 2/10
# 143613/143613 [==============================] - 75s 521us/step - loss: 0.0409 - acc: 0.9839 - val_loss: 0.0390 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 2 - score: 0.989951
# Epoch 3/10
# 143613/143613 [==============================] - 76s 526us/step - loss: 0.0382 - acc: 0.9847 - val_loss: 0.0413 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 3 - score: 0.990815
# Epoch 4/10
# 143613/143613 [==============================] - 76s 526us/step - loss: 0.0360 - acc: 0.9855 - val_loss: 0.0384 - val_acc: 0.9851
#
#  ROC-AUC - epoch: 4 - score: 0.990653
# Epoch 5/10
# 143613/143613 [==============================] - 75s 521us/step - loss: 0.0339 - acc: 0.9862 - val_loss: 0.0407 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 5 - score: 0.990885
# Epoch 6/10
# 143613/143613 [==============================] - 74s 517us/step - loss: 0.0317 - acc: 0.9870 - val_loss: 0.0394 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 6 - score: 0.990913
# Epoch 7/10
# 143613/143613 [==============================] - 74s 515us/step - loss: 0.0294 - acc: 0.9880 - val_loss: 0.0410 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 7 - score: 0.990401
# 153164/153164 [==============================] - 16s 102us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 77s 534us/step - loss: 0.0536 - acc: 0.9806 - val_loss: 0.0416 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 1 - score: 0.986578
# Epoch 2/10
# 143613/143613 [==============================] - 75s 522us/step - loss: 0.0408 - acc: 0.9838 - val_loss: 0.0395 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 2 - score: 0.989711
# Epoch 3/10
# 143613/143613 [==============================] - 76s 527us/step - loss: 0.0382 - acc: 0.9846 - val_loss: 0.0394 - val_acc: 0.9843
#
#  ROC-AUC - epoch: 3 - score: 0.990187
# Epoch 4/10
# 143613/143613 [==============================] - 77s 533us/step - loss: 0.0361 - acc: 0.9855 - val_loss: 0.0382 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 4 - score: 0.990834
# Epoch 5/10
# 143613/143613 [==============================] - 76s 531us/step - loss: 0.0339 - acc: 0.9862 - val_loss: 0.0386 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 5 - score: 0.990897
# Epoch 6/10
# 143613/143613 [==============================] - 76s 531us/step - loss: 0.0320 - acc: 0.9868 - val_loss: 0.0385 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 6 - score: 0.990565
# Epoch 7/10
# 143613/143613 [==============================] - 76s 532us/step - loss: 0.0296 - acc: 0.9879 - val_loss: 0.0396 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 7 - score: 0.990306
# 153164/153164 [==============================] - 16s 105us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 79s 550us/step - loss: 0.0545 - acc: 0.9804 - val_loss: 0.0414 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 1 - score: 0.987225
# Epoch 2/10
# 143613/143613 [==============================] - 76s 533us/step - loss: 0.0409 - acc: 0.9838 - val_loss: 0.0401 - val_acc: 0.9843
#
#  ROC-AUC - epoch: 2 - score: 0.989082
# Epoch 3/10
# 143613/143613 [==============================] - 77s 536us/step - loss: 0.0384 - acc: 0.9846 - val_loss: 0.0397 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 3 - score: 0.990582
# Epoch 4/10
# 143613/143613 [==============================] - 77s 534us/step - loss: 0.0363 - acc: 0.9854 - val_loss: 0.0391 - val_acc: 0.9843
#
#  ROC-AUC - epoch: 4 - score: 0.990919
# Epoch 5/10
# 143613/143613 [==============================] - 77s 533us/step - loss: 0.0339 - acc: 0.9861 - val_loss: 0.0399 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 5 - score: 0.990261
# Epoch 6/10
# 143613/143613 [==============================] - 77s 537us/step - loss: 0.0318 - acc: 0.9870 - val_loss: 0.0396 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 6 - score: 0.990322
# Epoch 7/10
# 143613/143613 [==============================] - 77s 539us/step - loss: 0.0294 - acc: 0.9880 - val_loss: 0.0416 - val_acc: 0.9834
#
#  ROC-AUC - epoch: 7 - score: 0.990492
# 153164/153164 [==============================] - 16s 106us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 80s 560us/step - loss: 0.0542 - acc: 0.9804 - val_loss: 0.0423 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 1 - score: 0.988103
# Epoch 2/10
# 143613/143613 [==============================] - 78s 540us/step - loss: 0.0409 - acc: 0.9838 - val_loss: 0.0402 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 2 - score: 0.990445
# Epoch 3/10
# 143613/143613 [==============================] - 77s 539us/step - loss: 0.0382 - acc: 0.9847 - val_loss: 0.0395 - val_acc: 0.9842
#
#  ROC-AUC - epoch: 3 - score: 0.990680
# Epoch 4/10
# 143613/143613 [==============================] - 78s 541us/step - loss: 0.0364 - acc: 0.9853 - val_loss: 0.0413 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 4 - score: 0.990647
# Epoch 5/10
# 143613/143613 [==============================] - 78s 540us/step - loss: 0.0343 - acc: 0.9861 - val_loss: 0.0392 - val_acc: 0.9840
#
#  ROC-AUC - epoch: 5 - score: 0.990394
# Epoch 6/10
# 143613/143613 [==============================] - 78s 540us/step - loss: 0.0321 - acc: 0.9870 - val_loss: 0.0399 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 6 - score: 0.990328
# Epoch 7/10
# 143613/143613 [==============================] - 78s 542us/step - loss: 0.0300 - acc: 0.9879 - val_loss: 0.0407 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 7 - score: 0.990031
# Epoch 8/10
# 143613/143613 [==============================] - 78s 541us/step - loss: 0.0277 - acc: 0.9887 - val_loss: 0.0432 - val_acc: 0.9833
#
#  ROC-AUC - epoch: 8 - score: 0.989485
# 153164/153164 [==============================] - 16s 103us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 81s 561us/step - loss: 0.0541 - acc: 0.9806 - val_loss: 0.0408 - val_acc: 0.9840
#
#  ROC-AUC - epoch: 1 - score: 0.986903
# Epoch 2/10
# 143613/143613 [==============================] - 77s 539us/step - loss: 0.0409 - acc: 0.9839 - val_loss: 0.0410 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 2 - score: 0.989990
# Epoch 3/10
# 143613/143613 [==============================] - 78s 541us/step - loss: 0.0381 - acc: 0.9847 - val_loss: 0.0391 - val_acc: 0.9851
#
#  ROC-AUC - epoch: 3 - score: 0.990335
# Epoch 4/10
# 143613/143613 [==============================] - 78s 543us/step - loss: 0.0362 - acc: 0.9854 - val_loss: 0.0387 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 4 - score: 0.990968
# Epoch 5/10
# 143613/143613 [==============================] - 78s 541us/step - loss: 0.0340 - acc: 0.9861 - val_loss: 0.0389 - val_acc: 0.9843
#
#  ROC-AUC - epoch: 5 - score: 0.990926
# Epoch 6/10
# 143613/143613 [==============================] - 78s 541us/step - loss: 0.0318 - acc: 0.9869 - val_loss: 0.0405 - val_acc: 0.9841
#
#  ROC-AUC - epoch: 6 - score: 0.990772
# Epoch 7/10
# 143613/143613 [==============================] - 78s 540us/step - loss: 0.0295 - acc: 0.9879 - val_loss: 0.0418 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 7 - score: 0.990131
# 153164/153164 [==============================] - 15s 100us/step

# %%
embedding_matrix = get_embedding("fasttext")
roc_eval = RocAucEvaluation(validation_data=(X_valid, y_valid))
early_stopping = EarlyStopping(patience=3, restore_best_weights=True)
n_models = 5
pred = np.zeros((X_test.shape[0], 6))
for _ in range(n_models):
    model = build_model(embedding_matrix=embedding_matrix)
    model.fit(X_train, y_train, batch_size=128, epochs=10,
              validation_data=(X_valid, y_valid),
              callbacks = [roc_eval, early_stopping])
    pred += model.predict(X_test, batch_size=1024, verbose=1)
pred /= n_models
submission = pd.read_csv("data/sample_submission.csv")
submission[classes] = pred
submission.to_csv("submission/v5_GRU_fasttext_preprocess_submission.csv.gz", compression="gzip", index=False)
# Out:
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 74s 514us/step - loss: 0.0538 - acc: 0.9808 - val_loss: 0.0409 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 1 - score: 0.987621
# Epoch 2/10
# 143613/143613 [==============================] - 74s 518us/step - loss: 0.0412 - acc: 0.9837 - val_loss: 0.0394 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 2 - score: 0.989989
# Epoch 3/10
# 143613/143613 [==============================] - 74s 519us/step - loss: 0.0386 - acc: 0.9845 - val_loss: 0.0388 - val_acc: 0.9850
#
#  ROC-AUC - epoch: 3 - score: 0.990684
# Epoch 4/10
# 143613/143613 [==============================] - 75s 521us/step - loss: 0.0369 - acc: 0.9852 - val_loss: 0.0378 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 4 - score: 0.990988
# Epoch 5/10
# 143613/143613 [==============================] - 75s 519us/step - loss: 0.0349 - acc: 0.9859 - val_loss: 0.0380 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 5 - score: 0.990862
# Epoch 6/10
# 143613/143613 [==============================] - 74s 517us/step - loss: 0.0330 - acc: 0.9865 - val_loss: 0.0394 - val_acc: 0.9842
#
#  ROC-AUC - epoch: 6 - score: 0.990784
# Epoch 7/10
# 143613/143613 [==============================] - 74s 518us/step - loss: 0.0307 - acc: 0.9875 - val_loss: 0.0399 - val_acc: 0.9841
#
#  ROC-AUC - epoch: 7 - score: 0.990488
# 153164/153164 [==============================] - 15s 100us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 75s 525us/step - loss: 0.0539 - acc: 0.9808 - val_loss: 0.0412 - val_acc: 0.9841
#
#  ROC-AUC - epoch: 1 - score: 0.986727
# Epoch 2/10
# 143613/143613 [==============================] - 74s 513us/step - loss: 0.0411 - acc: 0.9838 - val_loss: 0.0408 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 2 - score: 0.989490
# Epoch 3/10
# 143613/143613 [==============================] - 74s 515us/step - loss: 0.0386 - acc: 0.9845 - val_loss: 0.0400 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 3 - score: 0.990581
# Epoch 4/10
# 143613/143613 [==============================] - 74s 515us/step - loss: 0.0367 - acc: 0.9852 - val_loss: 0.0389 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 4 - score: 0.990188
# Epoch 5/10
# 143613/143613 [==============================] - 74s 514us/step - loss: 0.0350 - acc: 0.9859 - val_loss: 0.0383 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 5 - score: 0.990941
# Epoch 6/10
# 143613/143613 [==============================] - 74s 517us/step - loss: 0.0329 - acc: 0.9866 - val_loss: 0.0386 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 6 - score: 0.990741
# Epoch 7/10
# 143613/143613 [==============================] - 74s 515us/step - loss: 0.0311 - acc: 0.9873 - val_loss: 0.0398 - val_acc: 0.9843
#
#  ROC-AUC - epoch: 7 - score: 0.990647
# Epoch 8/10
# 143613/143613 [==============================] - 74s 515us/step - loss: 0.0288 - acc: 0.9883 - val_loss: 0.0409 - val_acc: 0.9842
#
#  ROC-AUC - epoch: 8 - score: 0.990457
# 153164/153164 [==============================] - 16s 104us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 75s 526us/step - loss: 0.0550 - acc: 0.9804 - val_loss: 0.0415 - val_acc: 0.9839
#
#  ROC-AUC - epoch: 1 - score: 0.987614
# Epoch 2/10
# 143613/143613 [==============================] - 74s 515us/step - loss: 0.0413 - acc: 0.9836 - val_loss: 0.0393 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 2 - score: 0.990616
# Epoch 3/10
# 143613/143613 [==============================] - 74s 516us/step - loss: 0.0385 - acc: 0.9846 - val_loss: 0.0398 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 3 - score: 0.990851
# Epoch 4/10
# 143613/143613 [==============================] - 74s 517us/step - loss: 0.0367 - acc: 0.9853 - val_loss: 0.0383 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 4 - score: 0.990887
# Epoch 5/10
# 143613/143613 [==============================] - 74s 516us/step - loss: 0.0348 - acc: 0.9859 - val_loss: 0.0387 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 5 - score: 0.990995
# Epoch 6/10
# 143613/143613 [==============================] - 74s 518us/step - loss: 0.0330 - acc: 0.9867 - val_loss: 0.0391 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 6 - score: 0.990639
# Epoch 7/10
# 143613/143613 [==============================] - 74s 518us/step - loss: 0.0310 - acc: 0.9874 - val_loss: 0.0397 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 7 - score: 0.990304
# 153164/153164 [==============================] - 15s 101us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 76s 529us/step - loss: 0.0554 - acc: 0.9802 - val_loss: 0.0421 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 1 - score: 0.986587
# Epoch 2/10
# 143613/143613 [==============================] - 74s 515us/step - loss: 0.0412 - acc: 0.9838 - val_loss: 0.0394 - val_acc: 0.9843
#
#  ROC-AUC - epoch: 2 - score: 0.990062
# Epoch 3/10
# 143613/143613 [==============================] - 74s 517us/step - loss: 0.0386 - acc: 0.9845 - val_loss: 0.0387 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 3 - score: 0.990633
# Epoch 4/10
# 143613/143613 [==============================] - 74s 518us/step - loss: 0.0369 - acc: 0.9852 - val_loss: 0.0381 - val_acc: 0.9852
#
#  ROC-AUC - epoch: 4 - score: 0.991009
# Epoch 5/10
# 143613/143613 [==============================] - 74s 519us/step - loss: 0.0349 - acc: 0.9860 - val_loss: 0.0397 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 5 - score: 0.990783
# Epoch 6/10
# 143613/143613 [==============================] - 74s 517us/step - loss: 0.0330 - acc: 0.9865 - val_loss: 0.0386 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 6 - score: 0.991084
# Epoch 7/10
# 143613/143613 [==============================] - 74s 517us/step - loss: 0.0309 - acc: 0.9875 - val_loss: 0.0392 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 7 - score: 0.990995
# 153164/153164 [==============================] - 16s 105us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 76s 531us/step - loss: 0.0545 - acc: 0.9805 - val_loss: 0.0414 - val_acc: 0.9839
#
#  ROC-AUC - epoch: 1 - score: 0.988319
# Epoch 2/10
# 143613/143613 [==============================] - 75s 519us/step - loss: 0.0409 - acc: 0.9837 - val_loss: 0.0390 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 2 - score: 0.990429
# Epoch 3/10
# 143613/143613 [==============================] - 75s 520us/step - loss: 0.0386 - acc: 0.9846 - val_loss: 0.0394 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 3 - score: 0.990670
# Epoch 4/10
# 143613/143613 [==============================] - 74s 519us/step - loss: 0.0367 - acc: 0.9852 - val_loss: 0.0386 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 4 - score: 0.990871
# Epoch 5/10
# 143613/143613 [==============================] - 74s 518us/step - loss: 0.0350 - acc: 0.9858 - val_loss: 0.0383 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 5 - score: 0.990671
# Epoch 6/10
# 143613/143613 [==============================] - 75s 520us/step - loss: 0.0330 - acc: 0.9865 - val_loss: 0.0391 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 6 - score: 0.990644
# Epoch 7/10
# 143613/143613 [==============================] - 75s 520us/step - loss: 0.0311 - acc: 0.9872 - val_loss: 0.0402 - val_acc: 0.9841
#
#  ROC-AUC - epoch: 7 - score: 0.990264
# Epoch 8/10
# 143613/143613 [==============================] - 75s 521us/step - loss: 0.0288 - acc: 0.9882 - val_loss: 0.0407 - val_acc: 0.9842
#
#  ROC-AUC - epoch: 8 - score: 0.989887
# 153164/153164 [==============================] - 16s 104us/step
