# %%
import warnings
warnings.simplefilter("ignore")
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)
import matplotlib.pyplot as plt
# %matplotlib inline
import gensim
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping
from keras.initializers import Constant
from keras.layers import (Input, Embedding, SpatialDropout1D, Bidirectional,
                          GlobalAveragePooling1D, GlobalMaxPooling1D,
                          LSTM, CuDNNLSTM, GRU, CuDNNGRU, concatenate, Dropout, Dense, Activation)
from keras.models import Model
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
NUM_WORDS = 50000
MAXLEN = 250
EMBEDDING_DIM = 300

# %%
class RocAucEvaluation(Callback):
    def __init__(self, validation_data):
        self.X_val, self.y_val = validation_data
    def on_epoch_end(self, epoch, logs=None):
        y_pred = self.model.predict(self.X_val, verbose=0)
        score = roc_auc_score(self.y_val, y_pred)
        print("\n ROC-AUC - epoch: {:d} - score: {:.6f}".format(epoch + 1, score))

# %%
train = pd.read_csv('data/train_preprocessed.csv')
test = pd.read_csv('data/test_preprocessed.csv')
train['comment_text'].fillna("", inplace=True)
test['comment_text'].fillna("", inplace=True)
classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
X_train_raw, y_train = train['comment_text'].str.lower(), train[classes].values
X_test_raw = test['comment_text'].str.lower()
tk = Tokenizer(num_words=NUM_WORDS)
tk.fit_on_texts(X_train_raw)
X_train = tk.texts_to_sequences(X_train_raw)
X_test = tk.texts_to_sequences(X_test_raw)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=0)
X_train = pad_sequences(X_train, maxlen=MAXLEN)
X_valid = pad_sequences(X_valid, maxlen=MAXLEN)
X_test = pad_sequences(X_test, maxlen=MAXLEN)
nb_words = min(NUM_WORDS, len(tk.word_index) + 1)

# %%
def get_coefs(word, *arr):
    return word, np.asarray(arr, dtype='float32')


def get_embedding(pretrained_word_vectors):
    if pretrained_word_vectors == "google":
        EMBEDDING_PATH = "../embeddings/GoogleNews-vectors-negative300.bin"
        embedding_index = gensim.models.KeyedVectors.load_word2vec_format(EMBEDDING_PATH, binary=True)
    if pretrained_word_vectors == "glove":
        EMBEDDING_PATH = "../embeddings/glove.840B.300d.txt"
        embedding_index = dict(get_coefs(*o.strip().split(" ")) for o in open(EMBEDDING_PATH))
    elif pretrained_word_vectors == "fasttext":
        EMBEDDING_PATH = "../embeddings/crawl-300d-2M.vec"
        embedding_index = dict(get_coefs(*o.strip().split(" ")) for o in open(EMBEDDING_PATH))
    embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
    for word, i in tk.word_index.items():
        if i >= NUM_WORDS:
            continue
        if pretrained_word_vectors == "google":
            try:
                embedding_vector = embedding_index.get_vector(word)
            except Exception:
                continue
            embedding_matrix[i] = embedding_vector
        else:
            embedding_vector = embedding_index.get(word)
            if embedding_vector is not None:
                embedding_matrix[i] = embedding_vector
    return embedding_matrix

# %%
def build_model(embedding_matrix):
    inputs = Input(shape=(MAXLEN,))
    x = Embedding(nb_words, EMBEDDING_DIM,
                  embeddings_initializer=Constant(embedding_matrix),
                  trainable=False)(inputs)
    x = SpatialDropout1D(0.2)(x)
    x1 = Bidirectional(CuDNNGRU(128, return_sequences=True))(x)
    x2 = Bidirectional(CuDNNLSTM(128, return_sequences=True))(x)
    avg_pool1 = GlobalAveragePooling1D()(x1)
    max_pool1 = GlobalMaxPooling1D()(x1)
    avg_pool2 = GlobalAveragePooling1D()(x2)
    max_pool2 = GlobalMaxPooling1D()(x2)
    x = concatenate([avg_pool1, max_pool1, avg_pool2, max_pool2])
    # x = Dense(64, activation='relu')(x)
    # x = Dropout(0.2)(x)
    outputs = Dense(6, activation="sigmoid")(x)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='binary_crossentropy', optimizer="adam", metrics=['accuracy'])
    return model

# %%
embedding_matrix = get_embedding("fasttext")
roc_eval = RocAucEvaluation(validation_data=(X_valid, y_valid))
early_stopping = EarlyStopping(patience=3, restore_best_weights=True)
n_models = 5
pred = np.zeros((X_test.shape[0], 6))
for _ in range(n_models):
    model = build_model(embedding_matrix=embedding_matrix)
    model.fit(X_train, y_train, batch_size=128, epochs=10,
              validation_data=(X_valid, y_valid),
              callbacks = [roc_eval, early_stopping])
    pred += model.predict(X_test, batch_size=1024, verbose=1)
pred /= n_models
submission = pd.read_csv("data/sample_submission.csv")
submission[classes] = pred
submission.to_csv("submission/v4_BiGRU_BiLSTM_glove_preprocess_submission.csv.gz", compression="gzip", index=False)
# Out:
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/sunxin/miniconda3/envs/qinhanmin-test/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 85s 592us/step - loss: 0.0557 - acc: 0.9803 - val_loss: 0.0417 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 1 - score: 0.988289
# Epoch 2/10
# 143613/143613 [==============================] - 86s 601us/step - loss: 0.0410 - acc: 0.9840 - val_loss: 0.0398 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 2 - score: 0.990417
# Epoch 3/10
# 143613/143613 [==============================] - 87s 603us/step - loss: 0.0388 - acc: 0.9846 - val_loss: 0.0393 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 3 - score: 0.990868
# Epoch 4/10
# 143613/143613 [==============================] - 87s 603us/step - loss: 0.0365 - acc: 0.9854 - val_loss: 0.0388 - val_acc: 0.9843
#
#  ROC-AUC - epoch: 4 - score: 0.990985
# Epoch 5/10
# 143613/143613 [==============================] - 86s 599us/step - loss: 0.0346 - acc: 0.9862 - val_loss: 0.0381 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 5 - score: 0.990963
# Epoch 6/10
# 143613/143613 [==============================] - 86s 598us/step - loss: 0.0327 - acc: 0.9869 - val_loss: 0.0388 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 6 - score: 0.990890
# Epoch 7/10
# 143613/143613 [==============================] - 86s 600us/step - loss: 0.0309 - acc: 0.9876 - val_loss: 0.0391 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 7 - score: 0.990684
# Epoch 8/10
# 143613/143613 [==============================] - 87s 603us/step - loss: 0.0288 - acc: 0.9884 - val_loss: 0.0400 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 8 - score: 0.990462
# 153164/153164 [==============================] - 16s 106us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 87s 605us/step - loss: 0.0553 - acc: 0.9804 - val_loss: 0.0423 - val_acc: 0.9832
#
#  ROC-AUC - epoch: 1 - score: 0.987743
# Epoch 2/10
# 143613/143613 [==============================] - 86s 596us/step - loss: 0.0412 - acc: 0.9838 - val_loss: 0.0392 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 2 - score: 0.990087
# Epoch 3/10
# 143613/143613 [==============================] - 86s 599us/step - loss: 0.0386 - acc: 0.9847 - val_loss: 0.0392 - val_acc: 0.9842
#
#  ROC-AUC - epoch: 3 - score: 0.990696
# Epoch 4/10
# 143613/143613 [==============================] - 86s 598us/step - loss: 0.0365 - acc: 0.9853 - val_loss: 0.0382 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 4 - score: 0.990935
# Epoch 5/10
# 143613/143613 [==============================] - 86s 598us/step - loss: 0.0345 - acc: 0.9862 - val_loss: 0.0392 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 5 - score: 0.990792
# Epoch 6/10
# 143613/143613 [==============================] - 86s 598us/step - loss: 0.0331 - acc: 0.9867 - val_loss: 0.0382 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 6 - score: 0.991174
# Epoch 7/10
# 143613/143613 [==============================] - 86s 601us/step - loss: 0.0308 - acc: 0.9876 - val_loss: 0.0388 - val_acc: 0.9850
#
#  ROC-AUC - epoch: 7 - score: 0.991001
# 153164/153164 [==============================] - 16s 107us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 87s 605us/step - loss: 0.0554 - acc: 0.9800 - val_loss: 0.0417 - val_acc: 0.9840
#
#  ROC-AUC - epoch: 1 - score: 0.986351
# Epoch 2/10
# 143613/143613 [==============================] - 85s 594us/step - loss: 0.0409 - acc: 0.9838 - val_loss: 0.0390 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 2 - score: 0.989936
# Epoch 3/10
# 143613/143613 [==============================] - 86s 597us/step - loss: 0.0384 - acc: 0.9848 - val_loss: 0.0386 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 3 - score: 0.990468
# Epoch 4/10
# 143613/143613 [==============================] - 86s 596us/step - loss: 0.0363 - acc: 0.9855 - val_loss: 0.0382 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 4 - score: 0.990705
# Epoch 5/10
# 143613/143613 [==============================] - 86s 597us/step - loss: 0.0345 - acc: 0.9862 - val_loss: 0.0381 - val_acc: 0.9851
#
#  ROC-AUC - epoch: 5 - score: 0.990798
# Epoch 6/10
# 143613/143613 [==============================] - 87s 603us/step - loss: 0.0326 - acc: 0.9869 - val_loss: 0.0387 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 6 - score: 0.990592
# Epoch 7/10
# 143613/143613 [==============================] - 86s 600us/step - loss: 0.0308 - acc: 0.9877 - val_loss: 0.0394 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 7 - score: 0.990288
# Epoch 8/10
# 143613/143613 [==============================] - 86s 599us/step - loss: 0.0294 - acc: 0.9882 - val_loss: 0.0404 - val_acc: 0.9841
#
#  ROC-AUC - epoch: 8 - score: 0.990255
# 153164/153164 [==============================] - 16s 107us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 86s 598us/step - loss: 0.0576 - acc: 0.9796 - val_loss: 0.0427 - val_acc: 0.9834
#
#  ROC-AUC - epoch: 1 - score: 0.985594
# Epoch 2/10
# 143613/143613 [==============================] - 85s 589us/step - loss: 0.0418 - acc: 0.9836 - val_loss: 0.0396 - val_acc: 0.9843
#
#  ROC-AUC - epoch: 2 - score: 0.989919
# Epoch 3/10
# 143613/143613 [==============================] - 85s 594us/step - loss: 0.0389 - acc: 0.9846 - val_loss: 0.0390 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 3 - score: 0.990536
# Epoch 4/10
# 143613/143613 [==============================] - 86s 597us/step - loss: 0.0371 - acc: 0.9852 - val_loss: 0.0385 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 4 - score: 0.990925
# Epoch 5/10
# 143613/143613 [==============================] - 85s 593us/step - loss: 0.0355 - acc: 0.9858 - val_loss: 0.0386 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 5 - score: 0.990758
# Epoch 6/10
# 143613/143613 [==============================] - 85s 594us/step - loss: 0.0341 - acc: 0.9863 - val_loss: 0.0402 - val_acc: 0.9840
#
#  ROC-AUC - epoch: 6 - score: 0.990368
# Epoch 7/10
# 143613/143613 [==============================] - 85s 593us/step - loss: 0.0326 - acc: 0.9869 - val_loss: 0.0392 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 7 - score: 0.990916
# 153164/153164 [==============================] - 16s 106us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 87s 608us/step - loss: 0.0564 - acc: 0.9799 - val_loss: 0.0422 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 1 - score: 0.986447
# Epoch 2/10
# 143613/143613 [==============================] - 85s 591us/step - loss: 0.0415 - acc: 0.9836 - val_loss: 0.0392 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 2 - score: 0.990164
# Epoch 3/10
# 143613/143613 [==============================] - 84s 585us/step - loss: 0.0389 - acc: 0.9845 - val_loss: 0.0393 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 3 - score: 0.990536
# Epoch 4/10
# 143613/143613 [==============================] - 83s 580us/step - loss: 0.0366 - acc: 0.9853 - val_loss: 0.0382 - val_acc: 0.9851
#
#  ROC-AUC - epoch: 4 - score: 0.990657
# Epoch 5/10
# 143613/143613 [==============================] - 83s 577us/step - loss: 0.0350 - acc: 0.9859 - val_loss: 0.0387 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 5 - score: 0.990883
# Epoch 6/10
# 143613/143613 [==============================] - 83s 577us/step - loss: 0.0330 - acc: 0.9866 - val_loss: 0.0411 - val_acc: 0.9833
#
#  ROC-AUC - epoch: 6 - score: 0.990852
# Epoch 7/10
# 143613/143613 [==============================] - 82s 574us/step - loss: 0.0310 - acc: 0.9874 - val_loss: 0.0397 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 7 - score: 0.990556
# 153164/153164 [==============================] - 16s 104us/step

# %%
embedding_matrix = get_embedding("fasttext")
roc_eval = RocAucEvaluation(validation_data=(X_valid, y_valid))
early_stopping = EarlyStopping(patience=3, restore_best_weights=True)
n_models = 5
pred = np.zeros((X_test.shape[0], 6))
for _ in range(n_models):
    model = build_model(embedding_matrix=embedding_matrix)
    model.fit(X_train, y_train, batch_size=128, epochs=10,
              validation_data=(X_valid, y_valid),
              callbacks = [roc_eval, early_stopping])
    pred += model.predict(X_test, batch_size=1024, verbose=1)
pred /= n_models
submission = pd.read_csv("data/sample_submission.csv")
submission[classes] = pred
submission.to_csv("submission/v4_BiGRU_BiLSTM_fasttext_preprocess_submission.csv.gz", compression="gzip", index=False)
# Out:
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 83s 579us/step - loss: 0.0562 - acc: 0.9800 - val_loss: 0.0412 - val_acc: 0.9840
#
#  ROC-AUC - epoch: 1 - score: 0.987873
# Epoch 2/10
# 143613/143613 [==============================] - 85s 589us/step - loss: 0.0416 - acc: 0.9837 - val_loss: 0.0410 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 2 - score: 0.988974
# Epoch 3/10
# 143613/143613 [==============================] - 84s 584us/step - loss: 0.0388 - acc: 0.9846 - val_loss: 0.0385 - val_acc: 0.9847
#
#  ROC-AUC - epoch: 3 - score: 0.990768
# Epoch 4/10
# 143613/143613 [==============================] - 84s 583us/step - loss: 0.0367 - acc: 0.9853 - val_loss: 0.0396 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 4 - score: 0.990927
# Epoch 5/10
# 143613/143613 [==============================] - 83s 580us/step - loss: 0.0349 - acc: 0.9860 - val_loss: 0.0384 - val_acc: 0.9850
#
#  ROC-AUC - epoch: 5 - score: 0.990856
# Epoch 6/10
# 143613/143613 [==============================] - 83s 579us/step - loss: 0.0329 - acc: 0.9868 - val_loss: 0.0402 - val_acc: 0.9839
#
#  ROC-AUC - epoch: 6 - score: 0.990814
# Epoch 7/10
# 143613/143613 [==============================] - 84s 582us/step - loss: 0.0309 - acc: 0.9875 - val_loss: 0.0392 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 7 - score: 0.990819
# Epoch 8/10
# 143613/143613 [==============================] - 83s 581us/step - loss: 0.0288 - acc: 0.9885 - val_loss: 0.0395 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 8 - score: 0.990791
# 153164/153164 [==============================] - 16s 104us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 84s 587us/step - loss: 0.0559 - acc: 0.9803 - val_loss: 0.0413 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 1 - score: 0.987254
# Epoch 2/10
# 143613/143613 [==============================] - 82s 572us/step - loss: 0.0411 - acc: 0.9838 - val_loss: 0.0394 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 2 - score: 0.990215
# Epoch 3/10
# 143613/143613 [==============================] - 83s 576us/step - loss: 0.0386 - acc: 0.9846 - val_loss: 0.0399 - val_acc: 0.9842
#
#  ROC-AUC - epoch: 3 - score: 0.990583
# Epoch 4/10
# 143613/143613 [==============================] - 83s 577us/step - loss: 0.0366 - acc: 0.9853 - val_loss: 0.0384 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 4 - score: 0.990719
# Epoch 5/10
# 143613/143613 [==============================] - 83s 578us/step - loss: 0.0346 - acc: 0.9861 - val_loss: 0.0387 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 5 - score: 0.990612
# Epoch 6/10
# 143613/143613 [==============================] - 83s 578us/step - loss: 0.0327 - acc: 0.9868 - val_loss: 0.0388 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 6 - score: 0.990738
# Epoch 7/10
# 143613/143613 [==============================] - 84s 582us/step - loss: 0.0307 - acc: 0.9877 - val_loss: 0.0394 - val_acc: 0.9845
#
#  ROC-AUC - epoch: 7 - score: 0.990765
# 153164/153164 [==============================] - 16s 104us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 84s 583us/step - loss: 0.0568 - acc: 0.9799 - val_loss: 0.0419 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 1 - score: 0.986014
# Epoch 2/10
# 143613/143613 [==============================] - 81s 566us/step - loss: 0.0418 - acc: 0.9837 - val_loss: 0.0396 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 2 - score: 0.989682
# Epoch 3/10
# 143613/143613 [==============================] - 82s 570us/step - loss: 0.0389 - acc: 0.9845 - val_loss: 0.0388 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 3 - score: 0.990777
# Epoch 4/10
# 143613/143613 [==============================] - 82s 573us/step - loss: 0.0366 - acc: 0.9854 - val_loss: 0.0386 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 4 - score: 0.990898
# Epoch 5/10
# 143613/143613 [==============================] - 83s 578us/step - loss: 0.0349 - acc: 0.9860 - val_loss: 0.0393 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 5 - score: 0.991041
# Epoch 6/10
# 143613/143613 [==============================] - 83s 578us/step - loss: 0.0331 - acc: 0.9867 - val_loss: 0.0385 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 6 - score: 0.990973
# Epoch 7/10
# 143613/143613 [==============================] - 83s 579us/step - loss: 0.0311 - acc: 0.9875 - val_loss: 0.0389 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 7 - score: 0.990656
# Epoch 8/10
# 143613/143613 [==============================] - 84s 583us/step - loss: 0.0292 - acc: 0.9883 - val_loss: 0.0402 - val_acc: 0.9843
#
#  ROC-AUC - epoch: 8 - score: 0.990609
# Epoch 9/10
# 143613/143613 [==============================] - 83s 581us/step - loss: 0.0268 - acc: 0.9893 - val_loss: 0.0424 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 9 - score: 0.990280
# 153164/153164 [==============================] - 16s 104us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 86s 599us/step - loss: 0.0570 - acc: 0.9796 - val_loss: 0.0416 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 1 - score: 0.985905
# Epoch 2/10
# 143613/143613 [==============================] - 83s 580us/step - loss: 0.0417 - acc: 0.9837 - val_loss: 0.0394 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 2 - score: 0.990091
# Epoch 3/10
# 143613/143613 [==============================] - 83s 580us/step - loss: 0.0389 - acc: 0.9845 - val_loss: 0.0391 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 3 - score: 0.990745
# Epoch 4/10
# 143613/143613 [==============================] - 84s 583us/step - loss: 0.0368 - acc: 0.9852 - val_loss: 0.0383 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 4 - score: 0.990877
# Epoch 5/10
# 143613/143613 [==============================] - 84s 585us/step - loss: 0.0349 - acc: 0.9860 - val_loss: 0.0380 - val_acc: 0.9850
#
#  ROC-AUC - epoch: 5 - score: 0.991005
# Epoch 6/10
# 143613/143613 [==============================] - 85s 589us/step - loss: 0.0332 - acc: 0.9866 - val_loss: 0.0384 - val_acc: 0.9850
#
#  ROC-AUC - epoch: 6 - score: 0.990990
# Epoch 7/10
# 143613/143613 [==============================] - 84s 584us/step - loss: 0.0312 - acc: 0.9876 - val_loss: 0.0398 - val_acc: 0.9842
#
#  ROC-AUC - epoch: 7 - score: 0.990907
# Epoch 8/10
# 143613/143613 [==============================] - 84s 582us/step - loss: 0.0290 - acc: 0.9884 - val_loss: 0.0397 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 8 - score: 0.990811
# 153164/153164 [==============================] - 16s 104us/step
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/10
# 143613/143613 [==============================] - 89s 618us/step - loss: 0.0565 - acc: 0.9801 - val_loss: 0.0420 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 1 - score: 0.985783
# Epoch 2/10
# 143613/143613 [==============================] - 86s 599us/step - loss: 0.0417 - acc: 0.9836 - val_loss: 0.0404 - val_acc: 0.9841
#
#  ROC-AUC - epoch: 2 - score: 0.989854
# Epoch 3/10
# 143613/143613 [==============================] - 86s 601us/step - loss: 0.0389 - acc: 0.9845 - val_loss: 0.0387 - val_acc: 0.9849
#
#  ROC-AUC - epoch: 3 - score: 0.990858
# Epoch 4/10
# 143613/143613 [==============================] - 87s 608us/step - loss: 0.0369 - acc: 0.9852 - val_loss: 0.0392 - val_acc: 0.9846
#
#  ROC-AUC - epoch: 4 - score: 0.990854
# Epoch 5/10
# 143613/143613 [==============================] - 87s 608us/step - loss: 0.0352 - acc: 0.9860 - val_loss: 0.0382 - val_acc: 0.9852
#
#  ROC-AUC - epoch: 5 - score: 0.991140
# Epoch 6/10
# 143613/143613 [==============================] - 87s 609us/step - loss: 0.0335 - acc: 0.9865 - val_loss: 0.0386 - val_acc: 0.9848
#
#  ROC-AUC - epoch: 6 - score: 0.991071
# Epoch 7/10
# 143613/143613 [==============================] - 87s 609us/step - loss: 0.0316 - acc: 0.9874 - val_loss: 0.0391 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 7 - score: 0.991034
# Epoch 8/10
# 143613/143613 [==============================] - 88s 613us/step - loss: 0.0298 - acc: 0.9881 - val_loss: 0.0398 - val_acc: 0.9844
#
#  ROC-AUC - epoch: 8 - score: 0.990655
# 153164/153164 [==============================] - 16s 108us/step
